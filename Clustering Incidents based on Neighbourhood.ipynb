# %%
import pandas as pd

# %%
incidents = pd.read_csv('cleaned_incidents.csv')

# %%
incidents.head()
# Out:
#    Longitude  Latitude  Response_time  incident_id case_number  \
# 0     42.932   -78.852         300300          NaN  18-2600548
# 1     42.939   -78.848          53100          NaN  19-2790677
# 2     42.939   -78.850         167520          NaN  19-1400582
# 3     42.940   -78.851          67980          NaN  19-1750311
# 4     42.946   -78.851          54720          NaN  19-2580387
#
#        incident_datetime incident_type_primary  \
# 0   9/16/2018 7:00:00 AM         LARCENY/THEFT
# 1  10/6/2019 12:00:00 PM         LARCENY/THEFT
# 2   5/19/2019 7:00:00 PM         LARCENY/THEFT
# 3   6/23/2019 9:00:00 PM         LARCENY/THEFT
# 4  9/15/2019 12:00:00 AM         LARCENY/THEFT
#
#                                 incident_description                address  \
# 0  Buffalo Police are investigating this report o...  100 Block FLORENCE AV
# 1  Buffalo Police are investigating this report o...     1 Block RUSSELL ST
# ...

# %%
incidents = incidents.drop(['incident_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-5895426688de> in <module>
# ----> 1 incidents = incidents.drop(['incident_id'])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...
